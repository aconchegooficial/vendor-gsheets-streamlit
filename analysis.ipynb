# %%
import pandas as pd

# %%
df = pd.read_csv("cities.csv")
df.head()
# Out:
#                 CIDADE ESTADO LAVANDERIA PERFIL    UNIDADE DE ATENDIMENTO  \
# 0      Abadia de Goiás     GO        NaN    NaN                Goiânia/GO
# 1       Águas da Prata     SP        L01    NaN        Poços de Caldas/MG
# 2  Almirante Tamandaré     PR        NaN    P06                Colombo/PR
# 3  Almirante Tamandaré     PR        NaN    P06              Piraquara/PR
# 4               Altair     SP        L01    P11  São José do Rio Preto/SP
#
#   PREÇO A PARTIR DE PREÇO ANUNCIADO FRETE A PARTIR DE  INSTALAÇÃO  \
# 0           R$25,00         R$25,00             R$0,00        NaN
# 1           R$29,00         R$29,00             R$2/km        NaN
# 2           R$55,00         R$62,00             R$0,00     R$0,00
# 3           R$50,00         R$50,00             R$0,00     R$0,00
# 4           R$28,00         R$28,00             R$0,00     R$0,00
#
#   PEDIDO MÍNIMO POPULAÇÃO          STATUS DDD  \
# 0           NaN     8.958  fazer parceria  62
# ...

# %%
cities = df['CIDADE'].drop_duplicates(keep='first').values
manual_list = "["
for city in cities:
    manual_list += f"'{city}',"

manual_list
# Out:
# "['Abadia de Goiás','Águas da Prata','Almirante Tamandaré','Altair','Aparecida de Goiânia','Araquari','Araranguá','Araruna','Araucária','Arujá','Bady Bassitt','Balneário Camboriú','Balneário Piçarras','Balneário Rincão','Bálsamo','Barra Velha','Barroso','Barueri','Belo Horizonte','Bertioga','Biguaçu','Blumenau','Bombinhas','Botelhos','Brasília','Brusque','Caçapava','Cafelândia','Cajamar','Caldas','Camboriú','Campestre','Campina Grande do Sul','Campinas','Campo Largo','Campo Magro','Campo Mourão','Canelinha','Caraguatatuba','Carambeí','Carapicuíba','Castro','Catiguá','Cedral','Cerro Azul','Cianorte','Cocal do Sul','Colombo','Conceição da Barra de Minas (antiga Cassiterita)','Contenda','Coronel Xavier Chaves (antiga Coroas)','Cotia','Criciúma','Cruzeiro do Oeste','Cubatão','Curitiba','Diadema','Dores de Campos','Doutor Camargo','Embu das Artes','Embu-Guaçu','Estiva Gerbi','Fazenda Rio Grande','Ferraz de Vasconcelos','Florianópolis','Forquilhinha','Garça','Gaspar','Getulina','Goiânia','
# ...
